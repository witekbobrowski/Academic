# %% [markdown]
# # Statistical Methods

# %% [markdown]
# #### Imports

# %%
# %matplotlib inline
import numpy as np
import seaborn as sns
sns.set()

# %% [markdown]
# ## Task 1

# %%
sns.distplot(np.random.normal(0, 2, 10000), kde=False, fit=stats.gamma);

# %% [markdown]
# ## Task 2
